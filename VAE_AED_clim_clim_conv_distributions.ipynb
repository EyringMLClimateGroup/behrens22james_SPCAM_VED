# %%
## load some packages 
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import seaborn as sns

# %% [markdown]
# Load the saved latent spaces of VAE$_{clim \rightarrow clim + conv}$ and AE$_{clim \rightarrow clim + conv}$ for the SP test data.

# %%
VAE_clim_clim_conv_encoder=np.load('VAE_clim_clim_conv_encoder_pred_3_month_global.npy')

# %%
AED_clim_clim_conv_encoder=np.load('AED_clim_clim_conv_encoder_3month.npy')

# %% [markdown]
# # Compress the two latent spaces to 2D with PCA

# %%
VAE_pca=PCA(n_components=2).fit_transform(VAE_clim_clim_conv_encoder)

# %%
AED_pca=PCA(n_components=2).fit_transform(AED_clim_clim_conv_encoder)

# %% [markdown]
# Calculate the explained variance of the first PCs of the latent space of VAE$_{clim \rightarrow clim + conv}$

# %%
VAE_pca_ = PCA(n_components=2)
VAE_pca_.fit(VAE_clim_clim_conv_encoder)


VAE_pca_expl_var=np.sum(VAE_pca_.explained_variance_ratio_)

# %%
print(VAE_pca_expl_var)# print explained variance
# Out:
# 0.8248744381119899

# %% [markdown]
# Calculate the explained variance of the first PCs of the latent space of AE$_{clim \rightarrow clim + conv}$

# %%
AED_pca_ = PCA(n_components=2)
AED_pca_.fit(AED_clim_clim_conv_encoder)


AED_pca_expl_var=np.sum(AED_pca_.explained_variance_ratio_)

# %%
print(AED_pca_expl_var)# explained variance of first two leading PCs of latent space of AE_clim_clim_conv
# Out:
# 0.6832694345977457

# %% [markdown]
# # Plot marginal distributions of the latent space of VAE$_{clim \rightarrow clim + conv}$

# %%
c_map=[[0,0,1,0.5],[0,0,0.6,1],[0,0,0,1],[0,0.4,0.5,1],[0.6,0.4,0,1]]
 # use same colorbar as in generative modelling plots

# %%
## first latent dimension
plt.figure(1,(5,4))

plt.hist(VAE_clim_clim_conv_encoder[:,0],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %%
# second latent dimension
plt.figure(1,(5,4))

plt.hist(VAE_clim_clim_conv_encoder[:,1],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %%
# third latent dimension
plt.figure(1,(5,4))

plt.hist(VAE_clim_clim_conv_encoder[:,2],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %%
# fourth latent dimension
plt.figure(1,(5,4))

plt.hist(VAE_clim_clim_conv_encoder[:,3],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %%
## fifth latent dimension
plt.figure(1,(5,4))

plt.hist(VAE_clim_clim_conv_encoder[:,4],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %% [markdown]
# # Plot marginal distributions of the latent space of AE$_{clim \rightarrow clim + conv}$

# %%
#first dimension AE latent space 
plt.figure(1,(5,4))

plt.hist(AED_clim_clim_conv_encoder[:,0],49,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,0]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)


plt.grid(True)

# %%
#second latent dimension of AE
plt.figure(1,(5,4))

plt.hist(AED_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)


plt.grid(True)

# %%
# third latent dimension of AE
plt.figure(1,(5,4))

plt.hist(AED_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)


plt.grid(True)

# %%
#4th latent dimensionof AE

plt.figure(1,(5,4))

plt.hist(AED_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)


plt.grid(True)

# %%
#5th latent dimension of AE

plt.figure(1,(5,4))

plt.hist(AED_clim_clim_conv_encoder[:,4],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,4]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)

plt.grid(True)

# %% [markdown]
# # Comparison plot between the marginal distributions of VAE$_{clim \rightarrow clim + conv}$ and AE$_{clim \rightarrow clim +conv}$

# %%
plt.figure(17,(20,9))

plt.subplot(2,5,1)

plt.hist(VAE_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)


ax_2=plt.subplot(2,5,2)

plt.hist(VAE_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)

plt.grid(True)
ax_2.set_yticklabels([])


ax_3=plt.subplot(2,5,3)

plt.title(r'VAE$_{clim \rightarrow clim + conv}$',Fontsize=20)


plt.hist(VAE_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],1),0,0.40,color=c_map[0],label= r'1$^{st}$ perc')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[1],label= r'10$^{th}$ perc')
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2],label= r'50$^{th}$ perc')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[3],label= r'90$^{th}$ perc')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],99),0,0.40,color=c_map[4],label= r'99$^{th}$ perc')
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
plt.legend(fontsize=12)
ax_3.set_yticklabels([])


ax_4=plt.subplot(2,5,4)

plt.hist(VAE_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
ax_4.set_yticklabels([])


ax_5=plt.subplot(2,5,5)

plt.hist(VAE_clim_clim_conv_encoder[:,4],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],10),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
ax_5.set_yticklabels([])


#AED


plt.subplot(2,5,6)

plt.hist(AED_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,0]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,0],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)

plt.xlabel('Latent node 0', Fontsize=16)


ax_7=plt.subplot(2,5,7)

plt.hist(AED_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,1],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
plt.xlabel('Latent node 1', Fontsize=16)
ax_7.set_yticklabels([])

ax_8=plt.subplot(2,5,8)

plt.title(r'AE$_{clim \rightarrow clim + conv}$',Fontsize=20)

plt.hist(AED_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,2],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
plt.xlabel('Latent node 2', Fontsize=16)
ax_8.set_yticklabels([])


ax_9=plt.subplot(2,5,9)

plt.hist(AED_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,3],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)
plt.xlabel('Latent node 3', Fontsize=16)
ax_9.set_yticklabels([])


ax_10=plt.subplot(2,5,10)

plt.hist(AED_clim_clim_conv_encoder[:,4],29,density=True,stacked=True,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],1),0,0.40,color=c_map[0])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],10),0,0.40,color=c_map[1])
plt.vlines(np.median(AED_clim_clim_conv_encoder[:,4]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],90),0,0.40,color=c_map[3])
plt.vlines(np.percentile(AED_clim_clim_conv_encoder[:,4],99),0,0.40,color=c_map[4])
plt.ylim(0,0.37)
plt.xlim(-30,30)

plt.xticks(fontsize=12)
plt.grid(True)

ax_10.set_yticklabels([])

plt.xlabel('Latent node 4', Fontsize=16)
# Out:
# <ipython-input-24-e894c77f46ab>:37: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title(r'VAE$_{clim \rightarrow clim + conv}$',Fontsize=20)
# <ipython-input-24-e894c77f46ab>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.xlabel('Latent node 0', Fontsize=16)
# <ipython-input-24-e894c77f46ab>:121: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.xlabel('Latent node 1', Fontsize=16)
# <ipython-input-24-e894c77f46ab>:126: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title(r'AE$_{clim \rightarrow clim + conv}$',Fontsize=20)
# ...

# %% [markdown]
# # Illustration of marginal distributions of VAE in 'step histograms' used for Figure 11 in paper

# %% [markdown]
# We swap the number of latent nodes here to sort into large-scale and sub-grid-scale notes.
#
# Original latent node 1 $\rightarrow$ Node 3
#
# Original latent node 2 $\rightarrow$ Node 2
#
# Original latent node 3 $\rightarrow$ Node 4
#
# Original latent node 4 $\rightarrow$ Node 5
#
# Original latent node 5 $\rightarrow$ Node 1

# %%
plt.figure(5,(4,18))
ax_1=plt.subplot(5,1,1)
plt.hist(VAE_clim_clim_conv_encoder[:,4],29,
         density=True,stacked=True,histtype='step',linewidth=3,
         color=[0,0.8,0.7,1],label='Node')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],10),
           0,0.40,color=c_map[0],label=r'10$^{th}$ per')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],25),
           0,0.40,color=c_map[1],label=r'25$^{th}$ per')
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),
           0,0.40,color=c_map[2],label=r'50$^{th}$ per')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],75),
           0,0.40,color=c_map[3],label=r'75$^{th}$ per')
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],90),
           0,0.40,color=c_map[4],label=r'90$^{th}$ per')
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.legend(fontsize=15,loc=2)

plt.title('Node 1',fontsize=20)
ax_1.set_xticklabels([])
ax_1.set_yticklabels([])
plt.grid(True)

ax_2=plt.subplot(5,1,2)
plt.hist(VAE_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.title('Latent Node 2',fontsize=20)
ax_2.set_xticklabels([])
ax_2.set_yticklabels([])
plt.grid(True)

ax_3=plt.subplot(5,1,3)
plt.hist(VAE_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,histtype='step',
         linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],10),
           0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],25),
           0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),
           0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],75),
           0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],90),
           0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.title('Latent Node 3',fontsize=20)
ax_3.set_xticklabels([])
ax_3.set_yticklabels([])
plt.grid(True)


ax_4=plt.subplot(5,1,4)
plt.hist(VAE_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.title('Latent Node 4',fontsize=20)
ax_4.set_xticklabels([])
ax_4.set_yticklabels([])
plt.grid(True)

ax_5=plt.subplot(5,1,5)
plt.hist(VAE_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.title('Latent Node 5',fontsize=20)
ax_5.set_xticklabels([])
ax_5.set_yticklabels([])
plt.grid(True)

# %% [markdown]
# This histogram plot below is used for the VAE summary schematic (Figure 11) in the paper

# %%
plt.figure(5,(4,15))
ax_1=plt.subplot(5,1,1)
plt.hist(VAE_clim_clim_conv_encoder[:,4],29,
         density=True,stacked=True,histtype='step',linewidth=3,
         color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],10),
           0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],25),
           0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),
           0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],75),
           0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,4],90),
           0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
plt.ylabel('Density',fontsize=24,loc='top')
plt.xlabel(r'Node 1',fontsize=24,loc='right')

ax_1.set_xticklabels([])
ax_1.set_yticklabels([])
plt.grid(True)
plt.tight_layout()

ax_2=plt.subplot(5,1,2)
plt.hist(VAE_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,1],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
ax_2.set_xticklabels([])
ax_2.set_yticklabels([])
plt.xlabel(r'Node 2',fontsize=24,loc='right')

plt.grid(True)

ax_3=plt.subplot(5,1,3)
plt.hist(VAE_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,histtype='step',
         linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],10),
           0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],25),
           0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),
           0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],75),
           0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,0],90),
           0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
ax_3.set_xticklabels([])
ax_3.set_yticklabels([])
plt.xlabel(r'Node 3',fontsize=24,loc='right')

plt.grid(True)


ax_4=plt.subplot(5,1,4)
plt.hist(VAE_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,2],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
ax_4.set_xticklabels([])
ax_4.set_yticklabels([])
plt.xlabel(r'Node 4',fontsize=24,loc='right')

plt.grid(True)

ax_5=plt.subplot(5,1,5)
plt.hist(VAE_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[4])
plt.ylim(0,0.15)
plt.xlim(-30,20)
ax_5.set_xticklabels([])
ax_5.set_yticklabels([])
plt.xlabel(r'Node 5',fontsize=24,loc='right')

plt.grid(True)

# %%
plt.figure(5,(12,3))
ax_1=plt.subplot(1,5,1)
plt.hist(VAE_clim_clim_conv_encoder[:,4],29,
         density=True,stacked=True,histtype='step',linewidth=3,
         color=[0,0.8,0.7,1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),
           0,0.40,color=c_map[2],label=r'50$^{th}$ perc')
plt.ylim(0,0.14)
plt.xlim(-30,30)

plt.title('Node 1',fontsize=15,y=-0.15)
ax_1.set_xticklabels([])
ax_1.set_yticklabels([])
plt.grid(True)

ax_2=plt.subplot(1,5,2)
plt.hist(VAE_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])

plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])

plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Node 2',fontsize=15,y=-0.15)
ax_2.set_xticklabels([])
ax_2.set_yticklabels([])
plt.grid(True)

ax_3=plt.subplot(1,5,3)
plt.hist(VAE_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,histtype='step',
         linewidth=3,color=[0,0.8,0.7,1])

plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),
           0,0.40,color=c_map[2])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Node 3',fontsize=15,y=-0.15)
ax_3.set_xticklabels([])
ax_3.set_yticklabels([])
plt.grid(True)


ax_4=plt.subplot(1,5,4)
plt.hist(VAE_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Node 4',fontsize=15,y=-0.15)
ax_4.set_xticklabels([])
ax_4.set_yticklabels([])
plt.grid(True)

ax_5=plt.subplot(1,5,5)
plt.hist(VAE_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[4])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Node 5',fontsize=15,y=-0.15)
ax_5.set_xticklabels([])
ax_5.set_yticklabels([])
plt.grid(True)

# %% [markdown]
# And also the plot below is used within Figure 11 of the paper to sketch the z$_{translation}$ approach on latent dimension 5. In this case all other latent dimensions are fixed to their median values and only the values along latent dimension 5 are varied.

# %%
plt.figure(5,(12,3))
ax_1=plt.subplot(1,5,1)
plt.hist(VAE_clim_clim_conv_encoder[:,4],29,
         density=True,stacked=True,histtype='step',linewidth=3,
         color=[0,0.8,0.7,1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,4]),
           0,0.40,color=c_map[2],label=r'50$^{th}$ perc')
plt.ylim(0,0.14)
plt.xlim(-30,30)

plt.title('Fixed',fontsize=19)
ax_1.set_xticklabels([])
ax_1.set_yticklabels([])
plt.grid(True)

ax_2=plt.subplot(1,5,2)
plt.hist(VAE_clim_clim_conv_encoder[:,1],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])

plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,1]),0,0.40,color=c_map[2])

plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Fixed',fontsize=19)
ax_2.set_xticklabels([])
ax_2.set_yticklabels([])
plt.grid(True)

ax_3=plt.subplot(1,5,3)
plt.hist(VAE_clim_clim_conv_encoder[:,0],29,density=True,stacked=True,histtype='step',
         linewidth=3,color=[0,0.8,0.7,1])

plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,0]),
           0,0.40,color=c_map[2])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Fixed',fontsize=19)
ax_3.set_xticklabels([])
ax_3.set_yticklabels([])
plt.grid(True)


ax_4=plt.subplot(1,5,4)
plt.hist(VAE_clim_clim_conv_encoder[:,2],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,2]),0,0.40,color=c_map[2])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Fixed',fontsize=17)
ax_4.set_xticklabels([])
ax_4.set_yticklabels([])
plt.grid(True)

ax_5=plt.subplot(1,5,5)
plt.hist(VAE_clim_clim_conv_encoder[:,3],29,density=True,stacked=True,histtype='step',linewidth=3,color=[0,0.8,0.7,1])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],10),0,0.40,color=c_map[0])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],25),0,0.40,color=c_map[1])
plt.vlines(np.median(VAE_clim_clim_conv_encoder[:,3]),0,0.40,color=c_map[2])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],75),0,0.40,color=c_map[3])
plt.vlines(np.percentile(VAE_clim_clim_conv_encoder[:,3],90),0,0.40,color=c_map[4])
plt.ylim(0,0.14)
plt.xlim(-30,30)
plt.title('Varies',fontsize=19)
ax_5.set_xticklabels([])
ax_5.set_yticklabels([])
plt.grid(True)

# %% [markdown]
# # VAE PCA vs. AED PCA

# %% [markdown]
# The following plots illustrate kernel density estimated joint distributions of
# the 2D PCA compressed of VAE$_{clim \rightarrow clim + conv}$ and AE$_{clim \rightarrow clim +conv}$ shown in the supplemental material.

# %%
# select a subset of latent space samples for the computation of KDEs
rand_data=np.random.choice(VAE_clim_clim_conv_encoder[:,1].size,100000,replace=False)
import pandas as pd

# %%
# KDE plot for VAE_clim_clim_conv
plt.figure(1,figsize=(8,9))

sns.set(font_scale = 1.2)
VAE_plot=sns.jointplot(
    data=pd.Dataframe(VAE_pca[rand_data]),
    x=VAE_pca[rand_data,0],
    y=VAE_pca[rand_data,1],kind="kde")
VAE_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)
plt.suptitle(r'VAE',y=0.80,x=0.18,fontsize=24)

#plt.show(VAE_plot)
# KDE plot for AE_clim_clim_conv
plt.figure(2,figsize=(8,9))
AED_plot=sns.jointplot(
    data=pd.Datafram(AED_pca[rand_data]),
    x=AED_pca[rand_data,0],
    y=AED_pca[rand_data,1],kind="kde")
AED_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)
plt.suptitle(r'AE',y=0.80,x=0.18,fontsize=24)
#plt.show(AED_plot)
# Out:
# Text(0.18, 0.8, 'AE')

# %%
#change of nomenclature
#VAE--->VED
#AED--->ED

# KDE plot for VAE_clim_clim_conv
plt.figure(1,figsize=(8,9))

sns.set(font_scale = 1.2)
VAE_plot=sns.jointplot(data=pd.DataFrame(VAE_pca),
              x=VAE_pca[rand_data,0],
              y=VAE_pca[rand_data,1],color=[0,0.5,0.8,0.01])
VAE_plot.plot_joint(sns.kdeplot, color=[0,0,0.4,1], zorder=1, levels=12)
VAE_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)
plt.suptitle(r'VED',y=0.80,x=0.18,fontsize=24)

#plt.show(VAE_plot)
# KDE plot for AE_clim_clim_conv
plt.figure(2,figsize=(8,9))
AED_plot=sns.jointplot(
    data=pd.DataFrame(AED_pca[rand_data]),
    x=AED_pca[rand_data,0],
    y=AED_pca[rand_data,1],color=[0,0.5,0.8,0.01])
AED_plot.plot_joint(sns.kdeplot, color=[0,0,0.4,1], zorder=1, levels=12)
AED_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)
plt.suptitle(r'ED',y=0.80,x=0.18,fontsize=24)
#plt.show(AED_plot)
# Out:
# Text(0.18, 0.8, 'ED')

# %%
# use the same axis limits in the two plots
plt.figure(1,figsize=(8,9))

sns.set(font_scale = 1.2)
VAE_plot=sns.jointplot(
    data=VAE_pca[rand_data],
    x=VAE_pca[rand_data,0],
    y=VAE_pca[rand_data,1],
    xlim=(-22,30),
    ylim=(-15,20),
    kind="kde")
VAE_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)

plt.suptitle(r'VAE',y=0.80,x=0.18,fontsize=24)
#plt.show(VAE_plot)

plt.figure(2,figsize=(8,9))
AED_plot=sns.jointplot(
    data=AED_pca[rand_data],
    x=AED_pca[rand_data,0],
    y=AED_pca[rand_data,1],
    xlim=(-22,30),
    ylim=(-15,20),
    kind="kde")
AED_plot.set_axis_labels('PC 1', 'PC 2', fontsize=20)

plt.suptitle(r'AE',y=0.80,x=0.18,fontsize=24)
#plt.show(AED_plot)
# Out:
# Text(0.18, 0.8, 'AE')
